# %%
# !pip install Faker
# !python.exe -m pip install --upgrade pip

# %%
import pandas as pd
from random import randint

for i in range(10):
    print(randint(15, 200))
# Out:
# 93
# 102
# 163
# 192
# 121
# 162
# 118
# 132
# 106
# 92

# %%
# df_struct = {
#     "processing_time_gen_ai": 21612.0,
#     "processing_time_trad_ai": 25.0
# }
# headr = ["processing_time_gen_ai", "processing_time_trad_ai"]

# df = pd.DataFrame(columns=headr)

# %%
dict = {
    "processing_time_gen_ai":[21612.0, 21378.0, 21287.0, 20987.0, 20678.0], 
    "processing_time_trad_ai":[25.0, 27.9, 22.8, 26.2, 25.8]
}
  
# df = pd.DataFrame(dict)

# %%
df
# Out:
#    processing_time_gen_ai  processing_time_trad_ai
# 0                 21612.0                     25.0
# 1                 21378.0                     27.9
# 2                 21287.0                     22.8
# 3                 20987.0                     26.2
# 4                 20678.0                     25.8

# %%
dict
# Out:
# {'processing_time_gen_ai': [21612.0,
#   21378.0,
#   21287.0,
#   20987.0,
#   20678.0,
#   20007.7,
#   20335.1,
#   21005.1,
#   21345.1,
#   20751.0,
#   20091.5,
#   20448.7,
#   20281.8,
#   21510.1,
#   20171.3,
#   20941.2,
#   20587.4,
#   21466.1,
#   20227.5,
#   20865.6,
#   20645.9,
#   20175.7,
#   21116.9,
#   21073.5,
#   20323.6,
#   21292.4,
#   20548.5,
#   20394.0,
#   21006.9,
#   21165.6,
#   20433.9,
#   20985.9,
#   20622.3,
#   21283.0,
#   21519.6,
#   20049.8,
#   20845.5,
#   21038.6,
#   20337.5,
#   21070.1,
#   21192.3,
#   20364.0,
#   21321.1,
#   20858.5,
#   20567.5,
#   20402.4,
#   21456.8,
#   20797.9,
#   20150.0,
#   20128.9,
#   20487.1,
#   21289.1,
#   20451.1,
#   20354.6,
#   20654.5,
#   21255.9,
#   21552.6,
#   21257.2,
#   21556.6,
#   20788.9,
#   20524.4,
#   20597.0,
#   20871.4,
#   20211.3,
#   20421.6,
#   20739.0,
#   21157.1,
#   20461.0,
#   20080.4,
#   20037.0,
#   20760.2,
#   20372.6,
#   20732.4,
#   20986.0,
# ...

# %%
dict = {
    "processing_time_gen_ai":[21612.0, 21378.0, 21287.0, 20987.0, 20678.0], 
    "processing_time_trad_ai":[25.0, 27.9, 22.8, 26.2, 25.8]
}

# %%
# 5 - 104
for i in range(100):
    dict["processing_time_gen_ai"].append(float(randint(200000.0, 216120.0))/10.0)
    dict["processing_time_trad_ai"].append(float(randint(220.0, 270.0))/10.0)

# %%
# 105 - 355
for i in range(250):
    dict["processing_time_gen_ai"].append(float(randint(150000.0, 200000.0))/10.0)
    dict["processing_time_trad_ai"].append(float(randint(220.0, 270.0))/10.0)

# %%
# 355 - 855
for i in range(500):
    dict["processing_time_gen_ai"].append(float(randint(100000.0, 150000.0))/10.0)
    dict["processing_time_trad_ai"].append(float(randint(220.0, 270.0))/10.0)

# %%
# 355 - 855
for i in range(500):
    dict["processing_time_gen_ai"].append(float(randint(10000.0, 15000.0))/10.0)
    dict["processing_time_trad_ai"].append(float(randint(220.0, 270.0))/10.0)

# %%
# 355 - 855
for i in range(500):
    dict["processing_time_gen_ai"].append(float(randint(400.0, 900.0))/10.0)
    dict["processing_time_trad_ai"].append(float(randint(220.0, 270.0))/10.0)

# %%
# 355 - 855
for i in range(500):
    dict["processing_time_gen_ai"].append(float(randint(150.0, 350.0))/10.0)
    dict["processing_time_trad_ai"].append(float(randint(220.0, 270.0))/10.0)

# %%
dict
# Out:
# {'processing_time_gen_ai': [21612.0,
#   21378.0,
#   21287.0,
#   20987.0,
#   20678.0,
#   20983.6,
#   21391.2,
#   20597.3,
#   20774.8,
#   21575.2,
#   21052.4,
#   21146.8,
#   21403.0,
#   21019.2,
#   20447.6,
#   20672.4,
#   20475.4,
#   21341.4,
#   21375.0,
#   21442.8,
#   20876.8,
#   20032.0,
#   20054.7,
#   20777.8,
#   21293.9,
#   20792.9,
#   21172.2,
#   20673.2,
#   20534.3,
#   20982.7,
#   21068.7,
#   21378.7,
#   20241.4,
#   20088.3,
#   21362.3,
#   20095.1,
#   20547.1,
#   20912.8,
#   20935.0,
#   20898.5,
#   20991.9,
#   20327.4,
#   20924.7,
#   20121.5,
#   20924.0,
#   21283.0,
#   20415.3,
#   20241.1,
#   20199.5,
#   21054.0,
#   21224.2,
#   20273.5,
#   21064.4,
#   21587.1,
#   21106.0,
#   20409.7,
#   20480.0,
#   20185.4,
#   21008.1,
#   20938.9,
#   20126.0,
#   21384.4,
#   21316.7,
#   21162.1,
#   20458.9,
#   20826.7,
#   20372.2,
#   21249.0,
#   20269.2,
#   21035.1,
#   20764.7,
#   21195.0,
#   21573.7,
#   20636.3,
# ...

# %%
df = pd.DataFrame(dict)

# %%
df
# Out:
#       processing_time_gen_ai  processing_time_trad_ai
# 0                    21612.0                     25.0
# 1                    21378.0                     27.9
# 2                    21287.0                     22.8
# 3                    20987.0                     26.2
# 4                    20678.0                     25.8
# ...                      ...                      ...
# 2350                    31.8                     22.7
# 2351                    28.4                     25.7
# 2352                    25.9                     22.5
# 2353                    21.7                     22.5
# 2354                    25.1                     27.0
#
# [2355 rows x 2 columns]

# %%
df.to_csv()
# Out:
# ',processing_time_gen_ai,processing_time_trad_ai\r\n0,21612.0,25.0\r\n1,21378.0,27.9\r\n2,21287.0,22.8\r\n3,20987.0,26.2\r\n4,20678.0,25.8\r\n5,20983.6,22.9\r\n6,21391.2,26.1\r\n7,20597.3,23.4\r\n8,20774.8,22.8\r\n9,21575.2,22.5\r\n10,21052.4,26.7\r\n11,21146.8,25.9\r\n12,21403.0,23.6\r\n13,21019.2,27.0\r\n14,20447.6,25.7\r\n15,20672.4,24.0\r\n16,20475.4,27.0\r\n17,21341.4,24.9\r\n18,21375.0,23.0\r\n19,21442.8,26.2\r\n20,20876.8,22.5\r\n21,20032.0,25.0\r\n22,20054.7,24.8\r\n23,20777.8,22.8\r\n24,21293.9,26.7\r\n25,20792.9,22.9\r\n26,21172.2,26.8\r\n27,20673.2,24.0\r\n28,20534.3,22.4\r\n29,20982.7,26.6\r\n30,21068.7,25.9\r\n31,21378.7,26.5\r\n32,20241.4,23.3\r\n33,20088.3,23.5\r\n34,21362.3,24.2\r\n35,20095.1,22.8\r\n36,20547.1,24.0\r\n37,20912.8,25.7\r\n38,20935.0,22.6\r\n39,20898.5,23.3\r\n40,20991.9,25.2\r\n41,20327.4,26.0\r\n42,20924.7,23.0\r\n43,20121.5,26.9\r\n44,20924.0,23.4\r\n45,21283.0,22.4\r\n46,20415.3,24.2\r\n47,20241.1,22.7\r\n48,20199.5,25.6\r\n49,21054.0,26.8\r\n50,212
# ...

# %%
df.to_csv('test_data.csv')

# %%
# !pip install --upgrade nbformat
# Out:
# ...
#    ---------------------------------------- 0.0/77.6 kB ? eta -:--:--
#    --------------------- ------------------ 41.0/77.6 kB 1.9 MB/s eta 0:00:01
#    ---------------------------------------- 77.6/77.6 kB 2.2 MB/s eta 0:00:00
# ...

# %%
import pandas as pd
import plotly.express as px

df = pd.read_csv("test_data.csv")

fig = px.line(df, y=['processing_time_gen_ai', 'processing_time_trad_ai'])
fig.show()
